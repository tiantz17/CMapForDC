# %%
import numpy as np
import pandas as pd
import os.path
import pickle
from scipy.stats import pearsonr, spearmanr

from cmapPy.pandasGEXpress.parse import parse # package from clue.io
import matplotlib.pyplot as plt

import numba as nb

# %%
@nb.njit(parallel=True)
def fastSort(a):
    b = np.empty(a.shape, dtype=np.int32)
    for i in nb.prange(a.shape[1]):
        b[:,i] = np.argsort(a[:,i])
    return b

def acc(P):
    """ accumulate matrix """
    for i in range(1, P.shape[0]):
        P[i] += P[i-1]
    return None
    
def ES(list_gene, profile):
    """ KS enrichment score"""
    if len(list_gene) == 0:
        return 0
    N, M = profile.shape[0], profile.shape[1]
    index = fastSort(-profile)
    rank = fastSort(index)
    # connectivity score in L1000 paper
    Nh = len(list_gene)
    Nr = np.zeros(M)
    P_hit = np.zeros((N, M))
    P_miss = np.ones((N, M))
    temp = np.array(range(M))
    profile = profile[index, temp]
    for i in list_gene:
        P_hit[rank[i], temp] = np.abs(profile[rank[i], temp])
        P_miss[rank[i], temp] = 0
        Nr += np.abs(profile[rank[i], temp])
    P_hit /= Nr
    P_miss /= N - Nh
    acc(P_hit)
    acc(P_miss)
    ES_score = P_hit - P_miss
    ES_score = ES_score[np.abs(ES_score).argmax(0), temp]

    return ES_score

def WTCS(list_up_index, list_dn_index, profile):
    """ weighted connectivity score """
    # shape: [978, M]
    batch_size = 10000
    M = profile.shape[1]
    num_batch = int(np.ceil(M / batch_size))
    wtcs_scores = np.zeros(M)
    for batch in range(num_batch):
        print("WTCS: {}/{}\r".format(batch+1, num_batch), end="")
        prof = profile[:, batch*batch_size:min(M, (batch+1)*batch_size)]
        ES_up = ES(list_up_index, prof)
        ES_dn = ES(list_dn_index, prof)
        wtcs = (ES_up - ES_dn) * 0.5 * (np.sign(ES_up) != np.sign(ES_dn))
        wtcs_scores[batch*batch_size:min(M, (batch+1)*batch_size)] = wtcs

    return wtcs_scores

# %%
####################################
# path to the LINCS data
####################################
path = '/data/tiantingzhong/LINCS2020/'

l1000file = "level5_beta_trt_cp_n720216x12328.gctx"
gene_info_file = "geneinfo_beta.txt"
sig_info_file  = "siginfo_beta_cp.txt"
pert_info_file = "compoundinfo_beta.txt"

# %%
pert_info = pd.read_csv(path + pert_info_file, sep="\t", low_memory=False)
gene_info = pd.read_csv(path + gene_info_file, sep="\t", dtype=str, low_memory=False)
sig_info = pd.read_csv(path + sig_info_file, sep="\t", low_memory=False)
sig_info = sig_info[sig_info['is_exemplar_sig'] == 1]
gene_landmark_rid = gene_info["gene_id"]
geneid2idx = {}
for i in gene_landmark_rid:
    geneid2idx[str(i)] = len(geneid2idx)

# %% [markdown]
# # Gene set of DC

# %%
up_geneset = [
    '7139', '3861', '800', '5210', '8061', '10205', '23452', '1783', '666', '7525', '4071', 
    '4313', '8425', '2919', '11167', '1848', '1291', '5654', '6662', '27289', '633', '3491', 
    '2615', '10626', '64787', '7077', '5742', '4131', '79971', '11127', '1893', '8848', '1514', 
    '51330', '2648', '7941', '79651', '9039', '1263', '1236', '1839', '1958', '6385', '822', 
    '5971', '664', '3949', '4792', '64114', '9123', '7378', '5211', '6513', '6275', '8870', 
    '894', '6277', '29923', '10982', '7167', '226', '836', '4794', '3659', '5315', '10938', 
    '4282', '4953', '4616', '9709'
] + ['23136', '5819', '4502']
dn_geneset = [
    '55723', '10403', '3835', '6402', '9133', '51172', '11133', '57405', '64924', '55143', 
    '23318', '84679', '374354', '332', '890', '891', '3009', '9212', '55872', '23623', '210', 
    '83461', '29071', '3575', '951', '10954', '3363', '3014', '23234', '10439', '3148', '221472', 
    '1152', '9555', '56650'
]
up_geneset = [geneid2idx[item] for item in up_geneset if item in geneid2idx]
dn_geneset = [geneid2idx[item] for item in dn_geneset if item in geneid2idx]
print('UP:', len(up_geneset))
print('DOWN:', len(dn_geneset))
# Out:
# UP: 73
# DOWN: 35

# %%
new_index = up_geneset + dn_geneset 
old2new = {}
for i,j in enumerate(new_index):
    old2new[j] = i
gene_dc_rid = gene_landmark_rid[new_index]

# %%
L1000 = parse(path + l1000file, rid=gene_dc_rid)
L1000 = L1000.data_df.loc[gene_dc_rid][sig_info['sig_id']]
L1000 = np.array(L1000)
print(L1000.shape)
# Out:
# (108, 136460)

# %%
new_cs = WTCS([old2new[i] for i in up_geneset], 
               [old2new[i] for i in dn_geneset], 
               L1000)
new_rank = np.argsort(np.argsort(-new_cs)) + 1
# Out:
# WTCS: 14/14

# %%
sig_info_rank = sig_info.copy()
sig_info_rank['new_cs'] = new_cs
sig_info_rank['new_rank'] = new_rank
sig_info_rank = sig_info_rank.sort_values('new_cs', ascending=False)
list_core_col = ['cmap_name', 'pert_id', 'pert_idose', 'pert_itime', 'cell_iname', 'is_exemplar_sig', 
                        'new_cs', 'new_rank',]
sig_info_rank_core = sig_info_rank[list_core_col]
sig_info_rank_core = sig_info_rank_core[sig_info_rank_core['is_exemplar_sig']==1]
new_rank = np.argsort(np.argsort(-sig_info_rank_core['new_cs'])) + 1
sig_info_rank_core['new_rank'] = new_rank
pert_moa = pert_info[['pert_id', 'moa']].drop_duplicates()
pertid2moa = {}
for i in pert_moa.index:
    pertid = pert_moa.loc[i, 'pert_id']
    moa = pert_moa.loc[i, 'moa']
    if pertid not in pertid2moa:
        pertid2moa[pertid] = str(moa)
    else:
        pertid2moa[pertid] += ";"+str(moa)
list_pertid = list(pertid2moa.keys())
list_moa = list([pertid2moa[i] for i in list_pertid])
table_moa = pd.DataFrame(np.array([list_pertid, list_moa], dtype=object).T, columns=['pert_id', 'moa'])
sig_info_rank_core = pd.merge(sig_info_rank_core, table_moa, on='pert_id', how='left')

# %%
sig_info_rank_core[sig_info_rank_core['moa'] != 'nan'][:30]
# Out:
#                 cmap_name        pert_id pert_idose pert_itime cell_iname  \
# 0             sitagliptin  BRD-K19416115    1.11 uM       24 h       MCF7
# 2               GR-127935  BRD-K11911061      10 uM       24 h       MCF7
# 3           cyclosporin-a  BRD-A38030642      10 uM        6 h       A549
# 16           VU-0418946-1  BRD-K44432556      10 uM        6 h      HEPG2
# 21            triciribine  BRD-A42649439      10 uM       24 h       MCF7
# 24       ingenol-mebutate  BRD-K93779381   0.125 uM       24 h   MDAMB231
# 25           progesterone  BRD-K64994968     100 uM       24 h     MCF10A
# 27             oxindole-I  BRD-K51816706      10 uM       24 h       MCF7
# 31          BRD-K00313977  BRD-K00313977      10 uM       24 h       MCF7
# 32              docetaxel  BRD-A05821830    0.04 uM       24 h     MCF10A
# 35                ingenol  BRD-A52650764      10 uM       24 h       A549
# 42           VU-0418946-1  BRD-K44432556      10 uM       24 h       MCF7
# 65             irinotecan  BRD-K08547377      10 uM        6 h       A375
# 67                JWE-035  BRD-K83972459      10 uM       24 h       HME1
# 69             crizotinib  BRD-K78431006      10 uM       24 h     MCF10A
# 80             oxindole-I  BRD-K51816706      10 uM        6 h      HEPG2
# 82               nutlin-3  BRD-A12230535    3.33 uM       24 h      HEPG2
# 83                BVT-948  BRD-A22713669      10 uM       24 h       MCF7
# 89              tamoxifen  BRD-K04210847      10 uM       24 h       MCF7
# 93       ingenol-mebutate  BRD-K93779381    1.11 uM       24 h       THP1
# 100                 PAC-1  BRD-K92991072      10 uM       24 h       A375
# 109          daunorubicin  BRD-A68009927    0.25 uM       24 h     MCF10A
# 111               DL-PDMP  BRD-K05653692      60 uM       24 h       MCF7
# 115             etoposide  BRD-A18419789      10 uM        6 h       A375
# 118                 TW-37  BRD-K28360340      10 uM       24 h     HCC515
# 119                5-BDBD  BRD-K33690734      10 uM       24 h       A375
# 121             salermide  BRD-A67788537     125 uM        6 h      NOMO1
# 127             PD-198306  BRD-K88677950      10 uM       24 h       MCF7
# 130               ingenol  BRD-A52650764      10 uM       24 h        PC3
# 132  azilsartan-medoxomil  BRD-K25723200      10 uM       24 h       A375
#
#      is_exemplar_sig    new_cs  new_rank  \
# 0                  1  0.836546         1
# 2                  1  0.833276         3
# 3                  1  0.828587         4
# 16                 1  0.810447        17
# 21                 1  0.803583        22
# 24                 1  0.800344        25
# 25                 1  0.798909        26
# 27                 1  0.798562        28
# 31                 1  0.793562        32
# 32                 1  0.793056        33
# 35                 1  0.792048        36
# 42                 1  0.789927        43
# 65                 1  0.778710        66
# 67                 1  0.778042        68
# 69                 1  0.776828        70
# 80                 1  0.773088        81
# 82                 1  0.772341        83
# 83                 1  0.772275        84
# 89                 1  0.769914        90
# 93                 1  0.769042        94
# 100                1  0.766667       101
# 109                1  0.763574       110
# 111                1  0.763431       112
# 115                1  0.762690       116
# 118                1  0.762346       119
# 119                1  0.762051       120
# 121                1  0.761294       122
# 127                1  0.760068       128
# 130                1  0.759727       131
# 132                1  0.759352       133
#
#                                                    moa
# 0                       Dipeptidyl peptidase inhibitor
# 2                        Serotonin receptor antagonist
# 3                                Calcineurin inhibitor
# 16                                       HIF modulator
# 21                                       Akt inhibitor
# 24                                       PKC activator
# 25                       Progesterone receptor agonist
# 27                                     VEGFR inhibitor
# 31                                      APEX inhibitor
# 32                                   Tubulin inhibitor
# 35                                       PKC activator
# 42                                       HIF modulator
# 65                             Topoisomerase inhibitor
# 67                             Aurora kinase inhibitor
# 69                                       ALK inhibitor
# 80                                     VEGFR inhibitor
# 82                                       MDM inhibitor
# 83                      Tyrosine phosphatase inhibitor
# 89   Estrogen receptor antagonist;Selective estroge...
# 93                                       PKC activator
# 100                                  Caspase activator
# 109    RNA synthesis inhibitor;Topoisomerase inhibitor
# 111                      Glucosyltransferase inhibitor
# 115                            Topoisomerase inhibitor
# 118                                      BCL inhibitor
# 119                     Purinergic receptor antagonist
# 121                                     SIRT inhibitor
# 127                 MEK inhibitor;MAP kinase inhibitor
# 130                                      PKC activator
# 132  Insulin sensitizer;Angiotensin antagonist;Angi...

# %%
temp = sig_info_rank_core[sig_info_rank_core['moa'] != 'nan']
temp_show = temp[:30][['cmap_name', 'pert_id', 'new_cs', 'moa']]
temp_show.columns = ['Compound name', 'Compound ID', 'Screening score', 'MOA']
temp_show = temp_show.reset_index(drop=True)
temp_show
# Out:
#            Compound name    Compound ID  Screening score  \
# 0            sitagliptin  BRD-K19416115         0.836546
# 1              GR-127935  BRD-K11911061         0.833276
# 2          cyclosporin-a  BRD-A38030642         0.828587
# 3           VU-0418946-1  BRD-K44432556         0.810447
# 4            triciribine  BRD-A42649439         0.803583
# 5       ingenol-mebutate  BRD-K93779381         0.800344
# 6           progesterone  BRD-K64994968         0.798909
# 7             oxindole-I  BRD-K51816706         0.798562
# 8          BRD-K00313977  BRD-K00313977         0.793562
# 9              docetaxel  BRD-A05821830         0.793056
# 10               ingenol  BRD-A52650764         0.792048
# 11          VU-0418946-1  BRD-K44432556         0.789927
# 12            irinotecan  BRD-K08547377         0.778710
# 13               JWE-035  BRD-K83972459         0.778042
# 14            crizotinib  BRD-K78431006         0.776828
# 15            oxindole-I  BRD-K51816706         0.773088
# 16              nutlin-3  BRD-A12230535         0.772341
# 17               BVT-948  BRD-A22713669         0.772275
# 18             tamoxifen  BRD-K04210847         0.769914
# 19      ingenol-mebutate  BRD-K93779381         0.769042
# 20                 PAC-1  BRD-K92991072         0.766667
# 21          daunorubicin  BRD-A68009927         0.763574
# 22               DL-PDMP  BRD-K05653692         0.763431
# 23             etoposide  BRD-A18419789         0.762690
# 24                 TW-37  BRD-K28360340         0.762346
# 25                5-BDBD  BRD-K33690734         0.762051
# 26             salermide  BRD-A67788537         0.761294
# 27             PD-198306  BRD-K88677950         0.760068
# 28               ingenol  BRD-A52650764         0.759727
# 29  azilsartan-medoxomil  BRD-K25723200         0.759352
#
#                                                   MOA
# 0                      Dipeptidyl peptidase inhibitor
# 1                       Serotonin receptor antagonist
# 2                               Calcineurin inhibitor
# 3                                       HIF modulator
# 4                                       Akt inhibitor
# 5                                       PKC activator
# 6                       Progesterone receptor agonist
# 7                                     VEGFR inhibitor
# 8                                      APEX inhibitor
# 9                                   Tubulin inhibitor
# 10                                      PKC activator
# 11                                      HIF modulator
# 12                            Topoisomerase inhibitor
# 13                            Aurora kinase inhibitor
# 14                                      ALK inhibitor
# 15                                    VEGFR inhibitor
# 16                                      MDM inhibitor
# 17                     Tyrosine phosphatase inhibitor
# 18  Estrogen receptor antagonist;Selective estroge...
# 19                                      PKC activator
# 20                                  Caspase activator
# 21    RNA synthesis inhibitor;Topoisomerase inhibitor
# 22                      Glucosyltransferase inhibitor
# 23                            Topoisomerase inhibitor
# 24                                      BCL inhibitor
# 25                     Purinergic receptor antagonist
# 26                                     SIRT inhibitor
# 27                 MEK inhibitor;MAP kinase inhibitor
# 28                                      PKC activator
# 29  Insulin sensitizer;Angiotensin antagonist;Angi...
